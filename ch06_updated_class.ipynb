# %% [markdown]
# # 6장 데이터 로딩과 저장, 파일 형식

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(10, 6))
pd.options.display.max_colwidth = 75
pd.options.display.max_columns = 20
np.set_printoptions(precision=4, suppress=True)
plt.rcParams["font.family"] = 'Malgun Gothic'

# %% [markdown]
# # 1. csv 텍스트 데이터
# ## 1.1 csv파일 읽기
# * 판다스에서 CSV 파일을 읽기: pd.read_csv(path, encoding = 'utf-8') 함수를 사용
#     * path 인수 : 파일시스템에서의 위치, URL, 파일객체를 나타내는 문자열
#     * encoding 인수 - 유니코드 인코딩 종류을 지정

# %% [markdown]
#     1) header(컬럼명)가 있는 파일

# %%
# !cat examples/ex1.csv

df = pd.read_csv("examples/ex1.csv", encoding= "utf-8") # csv file -> DataFrame으로 반환
type(df)
df.head(2)
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %% [markdown]
#     2) header가 없는 파일 : 컬럼을 지정
#         * names 인수 - 열 이름 리스트
#         * header 인수 - 헤더가 없을 경우 None으로 지정

# %%
# !cat examples/ex2.csv

names = ["a", "b", "c", "d", "message"]
data = pd.read_csv("examples/ex2.csv", names=names) #names 인수 - 데이터프레임의 컬럼명 지정
data
# Out:
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
#     3) 계층적 색인 지정하기
#         * index_col 인수 - 색인으로 사용할 열 번호나 이름, 계층적 색인을 지정할 경우 리스트

# %%
# !cat examples/csv_mindex.csv
parsed = pd.read_csv("examples/csv_mindex.csv",
                     index_col=["key1", "key2"])
parsed
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
#     4) 여러 개의 공백(spacebar)으로 필드를 구분한 파일 : txt포맷
#         * sep 인수 - 필드(컬럼)을 구분하기 위해 사용할 정규 표현식

# %%
# !cat examples/ex3.txt
result = pd.read_csv("examples/ex3.txt", sep="\s+") # 정규표현식 : " \s+  "
result
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hyung\AppData\Local\Temp\ipykernel_6732\3127721757.py:2: SyntaxWarning: invalid escape sequence '\s'
#   result = pd.read_csv("examples/ex3.txt", sep="\s+") # 정규표현식 : " \s+  "
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %% [markdown]
#     5) 주석을 갖고 있는 파일
#         * skiprows 인수 - 파일의 시작부터 무시할 행 수 또는 무시할 행 번호가 담긴 리스트

# %%
# !cat examples/ex4.csv
pd.read_csv("examples/ex4.csv", skiprows=[0, 2, 3])

# %% [markdown]
#     6) 누락된 값이 있는 파일 : 비어 있는 문자열, NA, NULL을 NaN으로 출력
#         * na_values 인수 - NA 값으로 처리할 값들의 목록

# %%
# !cat examples/ex5.csv
# na_values 인수을 사용하지 않은 경우
result = pd.read_csv("examples/ex5.csv")
result
# 1) 누락된 값을 확인 : isna(), isnull(), notna(), notnull()
pd.isna(result)

# 2) na_values -> 컬럼별 문자열 집합을 받아서 누락된 값 처리
sentinels = {"message": ["foo", "NA"], "something": ["two"]}
result = pd.read_csv("examples/ex5.csv", na_values=sentinels)
print(result)
result.isna()
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1       True  False  False   True  False    False
# 2      False  False  False  False  False     True

# %% [markdown]
#     7) 텍스트 파일 조금씩
#         * nrows 인수 - 파일의 첫 일부만 읽어올 때 처음 몇 줄을 읽을 것인지 지정
#         * chunksize 인수 - TextParser 객체에서 사용할 한 번에 익을 파일의 크기

# %%
#pd.options.display.max_rows = 10
# !cat examples/ex6.csv
# result = pd.read_csv("examples/ex6.csv")
# result
# result = pd.read_csv("examples/ex6.csv", nrows=5)
# result

# %% [markdown]
# ### [예제]  ex6.csv 파일을 순회하면서 "key"열의 값을 세기

# %%
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)
chunker
# type(chunker)
#1) 리스트의 시리즈 생성 - 청크 다위로 key"열의 값 저장
tot = pd.Series([], dtype='int64')
type(tot)
#2) 반복 처리 

for piece in chunker:
     # print(type(piece["key"]))
     # print(piece["key"].value_counts())
     tot = tot.add(piece["key"].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)
tot
tot[:10]
# Out:
# key
# E    368.0
# X    364.0
# L    346.0
# O    343.0
# Q    340.0
# M    338.0
# J    337.0
# F    335.0
# K    334.0
# H    330.0
# dtype: float64

# %%
# note
from pandas import Series
tot = pd.Series([], dtype='int64')
# type(tot) # Series

for piece in range(3):
    tot = tot.add(Series([1,2,3]), fill_value = 10) # tot + Series([1,2,3]
tot
# Out:
# 0    13.0
# 1    16.0
# 2    19.0
# dtype: float64

# %% [markdown]
# ## 1.2. csv 텍스트 파일 저장하기
# * 판다스에서 CSV 파일을 저장하기: df.to_csv(path, encoding = 'utf-8') 함수를 사용
#     * path 인수 : 파일시스템에서의 위치, URL, 파일객체를 나타내는 문자열
#     * encoding 인수 - 유니코드 인코딩 종류을 지정

# %%
# !cat examples/ex5.csv
# 1) 준비 : DataFrame
data = pd.read_csv("examples/ex5.csv") #-> DataFrame 반환
# 2. 조작 : DataFrame에서 인덱싱해서 필요한 데이터 추출-> DataFrame
data1 = data[['a','b','d']]
print(data1)
# # 3. data1 -> csv 파일로 저장
data1.to_csv("examples/out.csv")

# %%
data1.to_csv("examples/out.csv", sep="|") # 구분자 사용
data1.to_csv("examples/out.csv", na_rep = "NULL") #누락된 값을 원하는 값으로 지정
# data.to_csv("examples/out.csv", index=False, header=False)
data1.to_csv("examples/out.csv", index=False, columns=["a", "b", "d"])

# %% [markdown]
# # 2. JSON  데이터
# * JSON(JavaScript Object Notation)은 텍스트 데이터를 저장하고 전송하기 위한 일반적인 형식
# * 주로 웹에서 데이터를 전송하거나 저장하는 데 사용
# * JSON 파일은 일반적으로 텍스트 형식으로 작성되며, 사람과 기계 모두 이해하기 쉽다.
# * JSON 파일은 키-값 쌍의 모음으로 구성
#   * 키-값 쌍은 객체(object)라고도 하며, 중괄호 {} 로 묶는다.
#   * 배열(array)은 대괄호 [] 안에 값의 목록을 나열하여 정의.

# %% [markdown]
# ## 2.1 JSON 데이터 읽기/저장
#     * pandas의 to_json() -> 데이터프레임을 JSON 파일로 저장
#     * read_json() -> JSON 파일에서 데이터프레임을 읽어오기

# %% [markdown]
# ### [예제]  pandas의 to_json() 및 read_json() 메서드를 사용하여 데이터프레임을 JSON 파일로 저장하고 읽기

# %%
# 1. pandas 라이브러리 임포트
import pandas as pd

# 2. JSON 파일로 저장할 데이터프레임 생성
data = {
    "name": ["John", "Alice", "Bob"],
    "age": [30, 25, 35],
    "city": ["New York", "Los Angeles", "Chicago"]
}
df = pd.DataFrame(data)

# 3. 데이터프레임을 JSON 파일로 저장
df.to_json("examples/data.json")

# # JSON 파일을 읽어와 데이터프레임으로 변환
df_read = pd.read_json("examples/data.json")

print("Original DataFrame:")
print(df)

print("\nDataFrame from JSON file:")
print(df_read)
# Out:
# Original DataFrame:
#     name  age         city
# 0   John   30     New York
# 1  Alice   25  Los Angeles
# 2    Bob   35      Chicago
#
# DataFrame from JSON file:
#     name  age         city
# 0   John   30     New York
# 1  Alice   25  Los Angeles
# 2    Bob   35      Chicago

# %% [markdown]
# # 3. HTML 데이터
# ## 3.1 웹 스크래핑 - read_html()

# %% [markdown]
# * read_html() - html 문서 내 테이블 데이터 읽어 테이블 구조의 모든 데이터를 데이터프레임으로 저장해서 반환
#     * https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/

# %% [markdown]
# * 개발자 도구 사용 방법
#     * #s_content > div.section > ul > li:nth-child(1) > dl > dt > a

# %% [markdown]
# #### [예제] 미국 예금 보험 공사에서 부도 은행을 보여주는 HTML 문서 읽어오기

# %%
import pandas as pd
from pandas import Series, DataFrame

tables = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")
type(tables)
len(tables) # 1
failures = tables[0]
failures
type(failures)
failures.head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539

# %%
# 테이터프레임 가공
# 1) 컬럼명 수정하기
failures.columns
failures.columns = ['BankNameBank', 'CityCity', 'StateSt', 'CertCert',
       'AcquiringInstitutionAI', 'ClosingDate', 'FundFund']
failures.head(3)
# Out:
#                           BankNameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   AcquiringInstitutionAI        ClosingDate  FundFund
# 0              Iowa Trust & Savings Bank   November 3, 2023     10545
# 1                 Dream First Bank, N.A.      July 28, 2023     10544
# 2              JPMorgan Chase Bank, N.A.        May 1, 2023     10543
# 3                    Flagstar Bank, N.A.     March 12, 2023     10540
# 4    First–Citizens Bank & Trust Company     March 10, 2023     10539
# ..                                   ...                ...       ...
# 563                Superior Federal, FSB      July 27, 2001      6004
# 564                    North Valley Bank        May 3, 2001      4648
# 565  Southern New Hampshire Bank & Trust   February 2, 2001      4647
# 566              Banterra Bank of Marion  December 14, 2000      4646
# 567                   Bank of the Orient   October 13, 2000      4645
#
# [568 rows x 7 columns]

# %%
# 2) 데이터 변환 : 문자열 object -> datetime
close_timestamps = pd.to_datetime(failures["ClosingDate"]) # 컬럼 인덱싱
close_timestamps
#3) 년도별 부도난 은행의 개수 추출
close_timestamps.dt.year.value_counts() # Series
# Out:
# ClosingDate
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2023      5
# 2016      5
# 2020      4
# 2004      4
# 2019      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: count, dtype: int64

# %% [markdown]
# #### [실습] : 네이버 주식 데이터 가져오기 - read_html()
# * https://www.naver.com/ -> 증권 -> 국내증시 -> 시가총액
#     * https://finance.naver.com/sise/sise_market_sum.naver

# %%
# !pip install html5lib  lxml
# Out:
# Requirement already satisfied: html5lib in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (1.1)
# Requirement already satisfied: lxml in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (5.2.1)
# Requirement already satisfied: six>=1.9 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from html5lib) (0.5.1)

# %%
import pandas as pd

# 'euc-kr' 또는 'cp949'로 인코딩 설정하여 페이지 읽기 시도
df_list = pd.read_html("https://finance.naver.com/sise/sise_market_sum.naver",encoding = 'cp949')
type(df_list)
len(df_list)
type(df_list[1])
# 데이터프레임 확인
for df in df_list:
    print("\n",df.head())
# Out:
# C:\Users\hyung\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\bs4\__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# pandas.core.frame.DataFrame

# %%
# 데이터프레임 가공- 종목명에 NaN이 읶는 행은 제거
df = df_list[1] # 컬럼 인덱싱
df.head(10)
#boolean indexing 
df['종목명'] # 1. 컬럼 추출 -Series
df['종목명'].notnull() #2. 조건 색인
data = df[df['종목명'].notnull()] # 3. 조건색인으로 인덱싱하기
data
data.head()
# 가공한 데이터프레임을 파일로 저장
data.to_csv("examples/Naver_kospi.csv")
# Out:
#      N       종목명       현재가      전일비     등락률     액면가       시가총액      상장주식수  \
# 1  1.0      삼성전자   84300.0    700.0  +0.84%   100.0  5032527.0  5969783.0
# 2  2.0    SK하이닉스  186400.0   3500.0  +1.91%  5000.0  1356996.0   728002.0
# 3  3.0  LG에너지솔루션  371000.0   3000.0  -0.80%   500.0   868140.0   234000.0
# 4  4.0     삼성전자우   68700.0    400.0  +0.59%   100.0   565323.0   822887.0
# 5  5.0  삼성바이오로직스  792000.0  13000.0  -1.61%  2500.0   563698.0    71174.0
#
#    외국인비율         거래량    PER    ROE  토론실
# 1  55.81  12729078.0  39.56   4.15  NaN
# 2  54.74   1947497.0 -14.89 -15.61  NaN
# 3   4.90    109056.0  70.17   6.36  NaN
# 4  75.55    726112.0  32.24    NaN  NaN
# 5  11.99     31371.0  65.72   9.12  NaN

# %% [markdown]
# ## 3.2 웹 스크래핑 - requests

# %% [markdown]
# * 웹 페이지 정보 가져오기 - requests 패키지 이용
#   * requests.get()
#   * requests.get().status_code
#   * requests.get().text

# %% [markdown]
# ### [예제] 타겟 사이트의 json 구조로 저장된 데이터 가져오기

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from requests) (2024.2.2)

# %%
#1. requests 모듈 임포트하기
import requests
import pandas as pd
#2. url 가져오기
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
#pd.read_html(url)
# 3.페이지을 가져오기
resp = requests.get(url)
type(resp)
resp.status_code #200
resp.text # 데이터 가져오기
type(resp.text)

# 4. json 내용을 딕셔너리로 변환
data = resp.json() # json의 내용을 딕셔너리 형태로 변환한 객체을 반환
type(data)
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58215',
#   'id': 2236536541,
#   'node_id': 'PR_kwDOAA0YD85sS_5m',
#   'number': 58215,
#   'title': 'BUG: pandas.Series.unique() does not return correct unique values on non UTF8 enodeable strings',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-10T22:30:52Z',
#   'updated_at': '2024-04-10T23:03:53Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58215',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58215',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58215.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58215.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #45929 (Replace xxxx with the GitHub issue number)\r\n\r\nRevival of https://github.com/pandas-dev/pandas/pull/55530',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58215/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58214',
#   'id': 2236156743,
#   'node_id': 'I_kwDOAA0YD86FSQtH',
#   'number': 58214,
#   'title': "DEPR: rename 'dtype_backend'",
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-10T18:08:33Z',
#   'updated_at': '2024-04-10T21:43:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'This came up in #58141.  Discussed briefly at the sprint in August.\r\n\r\nI\'ve seen some user confusion [citation needed] stemming from the term "backend" in the "dtype_backend" parameter.  It gives the incorrect impression that behaviors are the same across backends, just with different implementations or performance characteristics.\r\n\r\nI think we should move away from "backend", renaming the dtype_backend parameter where applicable (with a deprecation cycle where appropriate).  Maybe dtype "family"?\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58214/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58213',
#   'id': 2236121810,
#   'node_id': 'PR_kwDOAA0YD85sRkZ6',
#   'number': 58213,
#   'title': 'DOC: update DatetimeTZDtype unit limitation',
#   'user': {'login': 'yokomotod',
#    'id': 825732,
#    'node_id': 'MDQ6VXNlcjgyNTczMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/825732?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yokomotod',
#    'html_url': 'https://github.com/yokomotod',
#    'followers_url': 'https://api.github.com/users/yokomotod/followers',
#    'following_url': 'https://api.github.com/users/yokomotod/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yokomotod/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yokomotod/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yokomotod/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yokomotod/orgs',
#    'repos_url': 'https://api.github.com/users/yokomotod/repos',
#    'events_url': 'https://api.github.com/users/yokomotod/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yokomotod/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-10T17:44:15Z',
#   'updated_at': '2024-04-10T21:34:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58213',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58213',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58213.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58213.patch',
#    'merged_at': None},
#   'body': '- [x] closes #58212\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58213/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58212',
#   'id': 2236117805,
#   'node_id': 'I_kwDOAA0YD86FSHMt',
#   'number': 58212,
#   'title': 'DOC: DatetimeTZDtype unit limitation is not updated',
#   'user': {'login': 'yokomotod',
#    'id': 825732,
#    'node_id': 'MDQ6VXNlcjgyNTczMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/825732?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yokomotod',
#    'html_url': 'https://github.com/yokomotod',
#    'followers_url': 'https://api.github.com/users/yokomotod/followers',
#    'following_url': 'https://api.github.com/users/yokomotod/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yokomotod/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yokomotod/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yokomotod/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yokomotod/orgs',
#    'repos_url': 'https://api.github.com/users/yokomotod/repos',
#    'events_url': 'https://api.github.com/users/yokomotod/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yokomotod/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-10T17:41:35Z',
#   'updated_at': '2024-04-10T17:48:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DatetimeTZDtype.html\r\n\r\n> unit: str, default “ns”\r\n> The precision of the datetime data. Currently limited to "ns".****\n\n### Documentation problem\n\nThe document says `Currently limited to "ns".`,  but actually `DatetimeTZDtype` seems to support non-nano since https://github.com/pandas-dev/pandas/pull/47120 \r\n\r\n\n\n### Suggested fix for documentation\n\nIt should be like `Currently limited to "s", "ms", "us", "ns".`',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58212/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58210',
#   'id': 2235864519,
#   'node_id': 'I_kwDOAA0YD86FRJXH',
#   'number': 58210,
#   'title': 'BUG: API Inconsistency between numeric_only and select_dtypes(["number"])',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1741841389,
#     'node_id': 'MDU6TGFiZWwxNzQxODQxMzg5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20-%20Consistency',
#     'name': 'API - Consistency',
#     'color': 'b60205',
#     'default': False,
#     'description': 'Internal Consistency of API/Behavior'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-10T15:19:53Z',
#   'updated_at': '2024-04-10T15:20:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nIn [25]: df = pd.DataFrame({"bool": [True, False, True], "int": [1, 2, 3]})\r\n\r\nIn [26]: df.sum(numeric_only=True)\r\nOut[26]: \r\nbool    2\r\nint     6\r\ndtype: int64\r\n\r\nIn [27]: df.select_dtypes(include=["number"]).sum()\r\nOut[27]: \r\nint    6\r\ndtype: int64\r\n```\n```\n\n\n### Issue Description\n\n`numeric_only=True` includes boolean values, whereas `select_dtypes(include=["number"])` does not\n\n### Expected Behavior\n\nIf judging by the NumPy type hierarchy the latter is more correct\r\n\r\nhttps://numpy.org/doc/stable/reference/arrays.scalars.html\n\n### Installed Versions\n\n\'3.0.0.dev0+681.g434fda08cf\'',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58210/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58207',
#   'id': 2234587961,
#   'node_id': 'I_kwDOAA0YD86FMRs5',
#   'number': 58207,
#   'title': 'BUG: failed to roundtrip to pyarrow Table with ArrowDtype for DictionaryArray',
#   'user': {'login': 'wenjuno',
#    'id': 4373187,
#    'node_id': 'MDQ6VXNlcjQzNzMxODc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4373187?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wenjuno',
#    'html_url': 'https://github.com/wenjuno',
#    'followers_url': 'https://api.github.com/users/wenjuno/followers',
#    'following_url': 'https://api.github.com/users/wenjuno/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wenjuno/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wenjuno/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wenjuno/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wenjuno/orgs',
#    'repos_url': 'https://api.github.com/users/wenjuno/repos',
#    'events_url': 'https://api.github.com/users/wenjuno/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wenjuno/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-10T01:37:24Z',
#   'updated_at': '2024-04-10T01:37:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pyarrow as pa\r\nimport pandas as pd\r\n\r\ntbl = pa.table({\'a\': pa.array([\'a\', \'b\']).dictionary_encode()})\r\ndf = tbl.to_pandas(types_mapper=pd.ArrowDtype)\r\ntbl2 = pa.Table.from_pandas(df)\r\ndf2 = tbl2.to_pandas(types_mapper=pd.ArrowDtype)\n```\n\n\n### Issue Description\n\nIt seems the arrow specific dtype from pandas is carried over to the pyarrow Table (`tbl2` in the example) and when trying to convert to pandas again (last line in the example constructing `df2`) it somehow cannot understand the metadata. I get this exception from it:\r\n```\r\nTraceback (most recent call last):\r\n  File "test_pandas_roundtrip.py", line 7, in <module>\r\n    df2 = tbl2.to_pandas(types_mapper=pd.ArrowDtype)\r\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "pyarrow/array.pxi", line 883, in pyarrow.lib._PandasConvertible.to_pandas\r\n  File "pyarrow/table.pxi", line 4251, in pyarrow.lib.Table._to_pandas\r\n  File "/tmp/arrow/lib/python3.11/site-packages/pyarrow/pandas_compat.py", line 769, in table_to_dataframe\r\n    ext_columns_dtypes = _get_extension_dtypes(\r\n                         ^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/tmp/arrow/lib/python3.11/site-packages/pyarrow/pandas_compat.py", line 828, in _get_extension_dtypes\r\n    pandas_dtype = _pandas_api.pandas_dtype(dtype)\r\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "pyarrow/pandas-shim.pxi", line 147, in pyarrow.lib._PandasAPIShim.pandas_dtype\r\n  File "pyarrow/pandas-shim.pxi", line 150, in pyarrow.lib._PandasAPIShim.pandas_dtype\r\n  File "/tmp/arrow/lib/python3.11/site-packages/pandas/core/dtypes/common.py", line 1645, in pandas_dtype\r\n    npdtype = np.dtype(dtype)\r\n              ^^^^^^^^^^^^^^^\r\n  File "/tmp/arrow/lib/python3.11/site-packages/numpy/core/_internal.py", line 176, in _commastring\r\n    raise ValueError(\r\nValueError: format number 1 of "dictionary<values=string, indices=int32, ordered=0>[pyarrow]" is not recognized\r\n```\n\n### Expected Behavior\n\nI expect to get the same DataFrame as the first DataFrame `df`.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.11.8.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 6.8.4-arch1-1\r\nVersion               : #1 SMP PREEMPT_DYNAMIC Fri, 05 Apr 2024 00:14:23 +0000\r\nmachine               : x86_64\r\nprocessor             :\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.1\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.9.0\r\nsetuptools            : 69.2.0\r\npip                   : 24.0\r\nCython                : None\r\npytest                : None\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : None\r\nIPython               : None\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : None\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : None\r\ngc ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58207/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58205',
#   'id': 2234507361,
#   'node_id': 'I_kwDOAA0YD86FL-Bh',
#   'number': 58205,
#   'title': 'BUG: Roundtripping bytes through pandas dataframes leads to data loss',
#   'user': {'login': 'maxburke',
#    'id': 253368,
#    'node_id': 'MDQ6VXNlcjI1MzM2OA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/253368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/maxburke',
#    'html_url': 'https://github.com/maxburke',
#    'followers_url': 'https://api.github.com/users/maxburke/followers',
#    'following_url': 'https://api.github.com/users/maxburke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/maxburke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/maxburke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/maxburke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/maxburke/orgs',
#    'repos_url': 'https://api.github.com/users/maxburke/repos',
#    'events_url': 'https://api.github.com/users/maxburke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/maxburke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-04-10T00:08:56Z',
#   'updated_at': '2024-04-10T14:44:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport hashlib\r\nimport pandas as pd\r\n\r\ndef hash_id(dgu_id: str) -> bytes:\r\n    h = hashlib.sha256()\r\n    h.update(dgu_id.encode())\r\n    id = h.digest()[0:16]\r\n    assert(len(id) == 16)\r\n    return id\r\n\r\ndf = pd.DataFrame({"id": ["2021A00051007067"]})\r\ndf["hash"] = df["id"].apply(hash_id).astype(bytes)\r\nassert len(df["hash"][0]) == 16\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIn the example above, the hash of the provided ID ends with a zero-byte (`b\'j\\x8b\\x93\\x1a\\xb5v2if\\xf3\\x10\\xe6\\x14/s\\x00\'`). When the resulting dataframe is inspected after, the entry is missing this trailing zero-byte (`b\'j\\x8b\\x93\\x1a\\xb5v2if\\xf3\\x10\\xe6\\x14/s\'`). In the example above, the second assertion, that the element is 16-bytes, fires even though the first assertion does not.\r\n\r\n### Expected Behavior\r\n\r\nI expect that the trailing zero byte is not dropped.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : fd3f57170aa1af588ba877e8e28c158a20a4886d\r\npython                : 3.10.0.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 23.4.0\r\nVersion               : Darwin Kernel Version 23.4.0: Wed Feb 21 21:44:43 PST 2024; root:xnu-10063.101.15~2/RELEASE_ARM64_T6000\r\nmachine               : arm64\r\nprocessor             : arm\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_CA.UTF-8\r\nLOCALE                : en_CA.UTF-8\r\n\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.8.2\r\nsetuptools            : 65.7.0\r\npip                   : 24.0\r\nCython                : None\r\npytest                : 7.4.4\r\nhypothesis            : None\r\nsphinx                : 6.1.3\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : 4.9.3\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : 2.9.9\r\njinja2                : 3.1.3\r\nIPython               : 8.12.3\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.3\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : 2024.2.0\r\ngcsfs                 : None\r\nmatplotlib            : 3.8.2\r\nnumba                 : 0.58.1\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : 3.1.2\r\npandas_gbq            : None\r\npyarrow               : 11.0.0\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : 1.12.0\r\nsqlalchemy            : 2.0.26\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : 2.0.1\r\nzstandard             : 0.19.0\r\ntzdata                : 2024.1\r\nqtpy                  : None\r\npyqt5                 : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58205/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58204',
#   'id': 2234451050,
#   'node_id': 'PR_kwDOAA0YD85sL42c',
#   'number': 58204,
#   'title': 'GH: PDEP vote issue template',
#   'user': {'login': 'Aloqeely',
#    'id': 52792999,
#    'node_id': 'MDQ6VXNlcjUyNzkyOTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52792999?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aloqeely',
#    'html_url': 'https://github.com/Aloqeely',
#    'followers_url': 'https://api.github.com/users/Aloqeely/followers',
#    'following_url': 'https://api.github.com/users/Aloqeely/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aloqeely/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aloqeely/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aloqeely/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aloqeely/orgs',
#    'repos_url': 'https://api.github.com/users/Aloqeely/repos',
#    'events_url': 'https://api.github.com/users/Aloqeely/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aloqeely/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-09T23:02:01Z',
#   'updated_at': '2024-04-09T23:15:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58204',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58204',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58204.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58204.patch',
#    'merged_at': None},
#   'body': 'Continuation of https://github.com/pandas-dev/pandas/pull/54469\r\nFeel free to preview this by opening an issue in my fork',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58204/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58197',
#   'id': 2233746993,
#   'node_id': 'PR_kwDOAA0YD85sJccV',
#   'number': 58197,
#   'title': 'Add low-level create_dataframe_from_blocks helper function',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-04-09T15:40:41Z',
#   'updated_at': '2024-04-10T16:51:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58197',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58197',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58197.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58197.patch',
#    'merged_at': None},
#   'body': 'See my explanation at https://github.com/pandas-dev/pandas/issues/56815/\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58197/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58191',
#   'id': 2233174897,
#   'node_id': 'I_kwDOAA0YD86FG4tx',
#   'number': 58191,
#   'title': 'BUG: Whether using pip or whl, i am unable to install pandas on my pc.',
#   'user': {'login': 'GaoRP',
#    'id': 92378125,
#    'node_id': 'U_kgDOBYGUDQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92378125?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GaoRP',
#    'html_url': 'https://github.com/GaoRP',
#    'followers_url': 'https://api.github.com/users/GaoRP/followers',
#    'following_url': 'https://api.github.com/users/GaoRP/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/GaoRP/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/GaoRP/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/GaoRP/subscriptions',
#    'organizations_url': 'https://api.github.com/users/GaoRP/orgs',
#    'repos_url': 'https://api.github.com/users/GaoRP/repos',
#    'events_url': 'https://api.github.com/users/GaoRP/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/GaoRP/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-09T11:00:31Z',
#   'updated_at': '2024-04-09T12:46:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nMicrosoft Windows [版本 10.0.19042.631]\r\n(c) 2020 Microsoft Corporation. 保留所有权利。\r\n\r\nC:\\Users\\T>pip install pandas\r\nLooking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple\r\nCollecting pandas\r\n  Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3d/59/2afa81b9fb300c90531803c0fd43ff4548074fa3e8d0f747ef63b3b5e77a/pandas-2.2.1.tar.gz (4.4 MB)\r\n  Installing build dependencies ... done\r\n  Getting requirements to build wheel ... done\r\n  Installing backend dependencies ... done\r\n  Preparing metadata (pyproject.toml) ... error\r\n  error: subprocess-exited-with-error\r\n\r\n  × Preparing metadata (pyproject.toml) did not run successfully.\r\n  │ exit code: 2\r\n  ╰─> [27 lines of output]\r\n      + meson setup C:\\Users\\T\\AppData\\Local\\Temp\\pip-install-zmuiyeag\\pandas_2222b59c0f8e4b79a46756caf4d840e2 C:\\Users\\T\\AppData\\Local\\Temp\\pip-install-zmuiyeag\\pandas_2222b59c0f8e4b79a46756caf4d840e2\\.mesonpy-vpzjukf0\\build -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --vsenv --native-file=C:\\Users\\T\\AppData\\Local\\Temp\\pip-install-zmuiyeag\\pandas_2222b59c0f8e4b79a46756caf4d840e2\\.mesonpy-vpzjukf0\\build\\meson-python-native-file.ini\r\n      Traceback (most recent call last):\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\mesonmain.py", line 194, in run\r\n          return options.run_func(options)\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\msetup.py", line 358, in run\r\n          app.generate()\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\msetup.py", line 178, in generate\r\n          env = environment.Environment(self.source_dir, self.build_dir, self.options)\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\environment.py", line 552, in __init__\r\n          config = coredata.parse_machine_files(self.coredata.config_files)\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\coredata.py", line 1030, in parse_machine_files\r\n          parser = MachineFileParser(filenames)\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\coredata.py", line 972, in __init__\r\n          self.parser.read(filenames)\r\n        File "C:\\Users\\T\\AppData\\Local\\Temp\\pip-build-env-f_2n0qyb\\overlay\\Lib\\site-packages\\mesonbuild\\coredata.py", line 959, in read\r\n          return super().read(filenames, encoding)\r\n        File "C:\\软件之家\\Python 3.10.11\\lib\\configparser.py", line 699, in read\r\n          self._read(fp, filename)\r\n        File "C:\\软件之家\\Python 3.10.11\\lib\\configparser.py", line 1022, in _read\r\n          for lineno, line in enumerate(fp, start=1):\r\n        File "C:\\软件之家\\Python 3.10.11\\lib\\codecs.py", line 322, in decode\r\n          (result, consumed) = self._buffer_decode(data, self.errors, final)\r\n      UnicodeDecodeError: \'utf-8\' codec can\'t decode byte 0xc8 in position 27: invalid continuation byte\r\n\r\n      ERROR: Unhandled python exception\r\n\r\n          This is a Meson bug and should be reported!\r\n      [end of output]\r\n\r\n  note: This error originates from a subprocess, and is likely not a problem with pip.\r\nerror: metadata-generation-failed\r\n\r\n× Encountered error while  ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58191/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58190',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58190/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58190/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58190/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58190',
#   'id': 2232326329,
#   'node_id': 'I_kwDOAA0YD86FDpi5',
#   'number': 58190,
#   'title': 'BUG: df.where(series, axis=1) always results in TypeError',
#   'user': {'login': 'wjandrea',
#    'id': 22385371,
#    'node_id': 'MDQ6VXNlcjIyMzg1Mzcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22385371?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wjandrea',
#    'html_url': 'https://github.com/wjandrea',
#    'followers_url': 'https://api.github.com/users/wjandrea/followers',
#    'following_url': 'https://api.github.com/users/wjandrea/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wjandrea/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wjandrea/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wjandrea/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wjandrea/orgs',
#    'repos_url': 'https://api.github.com/users/wjandrea/repos',
#    'events_url': 'https://api.github.com/users/wjandrea/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wjandrea/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2024-04-08T23:38:54Z',
#   'updated_at': '2024-04-09T08:58:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
# ...
#    'followers_url': 'https://api.github.com/users/dontgoto/followers',
#    'following_url': 'https://api.github.com/users/dontgoto/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dontgoto/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dontgoto/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dontgoto/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dontgoto/orgs',
#    'repos_url': 'https://api.github.com/users/dontgoto/repos',
#    'events_url': 'https://api.github.com/users/dontgoto/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dontgoto/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-05T19:28:25Z',
#   'updated_at': '2024-04-07T23:10:30Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58165',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58165',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58165.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58165.patch',
#    'merged_at': None},
#   'body': 'See my comments in #57951. This change in the benchmark input range has more coverage of the different logic branches in `np_datetime.c`. The benchmark should run about 1.8x as long (most likely a little bit machine dependent) after merging this.\r\n\r\nKeeping this separate from my other PR #57988 that improves the `np_datetime.c`performance to distinguish the benchmark impacts.\r\n\r\n@WillAyd \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58165/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58165/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58164',
#   'id': 2228632452,
#   'node_id': 'I_kwDOAA0YD86E1juE',
#   'number': 58164,
#   'title': 'BUILD: C code coverage',
#   'user': {'login': 'tdhock',
#    'id': 932850,
#    'node_id': 'MDQ6VXNlcjkzMjg1MA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/932850?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tdhock',
#    'html_url': 'https://github.com/tdhock',
#    'followers_url': 'https://api.github.com/users/tdhock/followers',
#    'following_url': 'https://api.github.com/users/tdhock/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tdhock/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tdhock/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tdhock/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tdhock/orgs',
#    'repos_url': 'https://api.github.com/users/tdhock/repos',
#    'events_url': 'https://api.github.com/users/tdhock/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tdhock/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-04-05T18:50:13Z',
#   'updated_at': '2024-04-07T13:39:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'Hi, I am doing mutation testing of pandas with @agroce \r\n\r\nI see five C source code files that are maintained by pandas, is that right?\r\n```\r\n_libs/src/datetime/date_conversions.c\r\n_libs/src/datetime/pd_datetime.c\r\n_libs/src/parser/tokenizer.c\r\n_libs/src/parser/pd_parser.c\r\n_libs/src/parser/io.c\r\n```\r\n\r\nI expected that pandas devs should be interested in the code coverage of these files, but on current coverage reports https://app.codecov.io/gh/pandas-dev/pandas/tree/main/pandas?search=&displayType=list there is no coverage computed for C files (only for py files).\r\n\r\nHow can the build/test scripts be modified so that C code coverage could be computed?\r\n\r\nOr is there a reason why code coverage for C files is not interesting?\r\n\r\nI searched the issue tracker for similar keywords, and the only related issue I saw is about coverage for Cython: https://github.com/pandas-dev/pandas/pull/54453\r\n\r\nThanks in advance.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58164/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58163',
#   'id': 2228560462,
#   'node_id': 'PR_kwDOAA0YD85r35X-',
#   'number': 58163,
#   'title': 'DOC: Add notes to nullable types documentation about pd.NA column type',
#   'user': {'login': 'giormala',
#    'id': 93475472,
#    'node_id': 'U_kgDOBZJSkA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93475472?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/giormala',
#    'html_url': 'https://github.com/giormala',
#    'followers_url': 'https://api.github.com/users/giormala/followers',
#    'following_url': 'https://api.github.com/users/giormala/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/giormala/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/giormala/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/giormala/subscriptions',
#    'organizations_url': 'https://api.github.com/users/giormala/orgs',
#    'repos_url': 'https://api.github.com/users/giormala/repos',
#    'events_url': 'https://api.github.com/users/giormala/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/giormala/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-05T18:10:45Z',
#   'updated_at': '2024-04-08T14:49:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58163',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58163',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58163.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58163.patch',
#    'merged_at': None},
#   'body': '- [X] closes #49201 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58163/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58160',
#   'id': 2228494923,
#   'node_id': 'I_kwDOAA0YD86E1CJL',
#   'number': 58160,
#   'title': "BUG: Segfault when calling df.to_json(orient='records') and numpy.datetime64 being serialized",
#   'user': {'login': 'paddymul',
#    'id': 40453,
#    'node_id': 'MDQ6VXNlcjQwNDUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40453?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paddymul',
#    'html_url': 'https://github.com/paddymul',
#    'followers_url': 'https://api.github.com/users/paddymul/followers',
#    'following_url': 'https://api.github.com/users/paddymul/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paddymul/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paddymul/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paddymul/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paddymul/orgs',
#    'repos_url': 'https://api.github.com/users/paddymul/repos',
#    'events_url': 'https://api.github.com/users/paddymul/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paddymul/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-04-05T17:24:41Z',
#   'updated_at': '2024-04-09T17:48:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nReproducing this bug has been very difficult.  I have a test script that runs off of my library repo that gets it to fail, but when trying to make a reduced testcase it doesn\'t fail.  Given that i\'m filing this against an old version of pandas, I\'ll just describe the bug to start.  I\'m happy to work with you to produce a reduced test case.\r\n\r\nThis is the code that should cause a segfault\r\n\r\nts = pd.Timestamp(\'2020-02-21T00:00:00.000000000\')\r\nnp_dt = pd.Series([ts]).mode().values[0]\r\nsdf = pd.DataFrame({\'a\':[ts], \'b\':[np_dt]}, index=[\'mode\'])\r\nsdf.to_json(orient=\'table\', indent=2, default_handler=str)\r\n\r\n\r\nMy actual code in the library (with print instrumentation)\r\n```python\r\ndef pd_to_obj(df:pd.DataFrame):\r\n    print("--------------")\r\n    print("here ser 86")\r\n\r\n    if len(df) > 4:\r\n        df = df[20:21]\r\n        print(df)\r\n        val = df.iloc[0][0]\r\n        print("val", val)\r\n        print("type(val)", type(val))\r\n\r\n    print("df.index", df.index)\r\n    print("len df", len(df))\r\n    serialized = df.to_json(orient=\'table\')\r\n    print("here ser 88")\r\n```\r\nthis fails at the `df.to_json` call.  Here is the debugging info outputted\r\n\r\n```\r\n--------------\r\nhere ser 86\r\n                          EventDate\r\nmode  2020-02-21T00:00:00.000000000\r\nval 2020-02-21T00:00:00.000000000\r\ntype(val) <class \'numpy.datetime64\'>\r\ndf.index Index([\'mode\'], dtype=\'object\')\r\nlen df 1\r\nzsh: segmentation fault  python crash_buckaroo.py\r\n```\n```\n\n\n### Issue Description\n\nPandas 2.0.3 segafaults when executing `to_json(orient=\'records\')`\n\n### Expected Behavior\n\nThere shouldn\'t be a segfault\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.10.14.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.6.0\r\nVersion          : Darwin Kernel Version 22.6.0: Wed Oct  4 21:25:40 PDT 2023; root:xnu-8796.141.3.701.17~4/RELEASE_ARM64_T8103\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.26.4\r\npytz             : 2024.1\r\ndateutil         : 2.9.0.post0\r\nsetuptools       : 68.2.2\r\npip              : 23.3.1\r\nCython           : None\r\npytest           : 8.1.1\r\nhypothesis       : None\r\nsphinx           : 7.2.6\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.3\r\nIPython          : 8.23.0\r\npandas_datareader: None\r\nbs4              : 4.12.3\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.8.4\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.13.0\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2024.1\r\n ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58160/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### [문제] 네이버 블로그의 키워드 관련 검색 결과 텍스트 데이터 가져오기 - requests 모듈 사용시 한계점

# %%
import requests
# url = "https://section.blog.naver.com/Search/Post.naver?\
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=%ED%8C%8C%EC%9D%B4%EC%8D%AC"

params = {
    'pageNo' : 1,
    'rangeType' : 'ALL',
    'orderBy' : 'sim',
    'keyword' : '파이썬'
}

#pd.read_html(url)
response = requests.get('https://section.blog.naver.com/Search/Post.naver?', params=params)

print(response.status_code) # HTTP GET 방식으로 URL 파라미터 값 전달
print(response.url) # status_code 는 응답코드
print(response.text) # text에는 HTML 코드
# Out:
# 200
# https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=%ED%8C%8C%EC%9D%B4%EC%8D%AC
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <base href="/home" />
#     <meta name="robots" content="noindex,nofollow"/>
#     <meta name="referrer" content="always"/>
#     <meta name="format-detection" content="telephone=no">
#     <link rel="shortcut icon" type="image/x-icon" href="https://section.blog.naver.com/favicon.ico?3"/>
#
#
#
#
#
#
#
#
# 		<meta property="og:title" content="파이썬 : 네이버 블로그"/>
#
#
#
#
# 			<meta property="og:image" content="https://blogimgs.pstatic.net/nblog/mylog/post/og_default_image_160610.png"/>
#
#
#         <meta property="og:description" content="당신의 모든 기록을 담는 공간"/>
#
#
#
#
#
# <meta property="me:feed:serviceId" content="blog" />
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#     <title>네이버 블로그</title>
#
#     <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/section/versioning/section_ngapp-246879052_https.css" charset="UTF-8" />
#
#     <script>
#         var angularConfig = {"isDev":false,"jeagleEyeDebug":false};
#         var readOnlyStatus = {"isReadOnly":false,"startTime":null,"endTime":null,"reason":null,"usageTip":null,"maintenanceType":null,"maintenancePeriod":null};
#         var urlMap = {"item2":"https://item2.naver.com","likeit":"https://blog.like.naver.com","admin":"https://admin.blog.naver.com","section":"https://section.blog.naver.com","blog":"https://blog.naver.com","mkt_p1":"https://mkt.naver.com/p1/","kin":"http://kin.naver.com","search":"http://search.naver.com","apigw_like":"https://apis.naver.com/blogserver/like","guestbook":"https://guestbook.blog.naver.com","beyond_analytics":"https://scv-blog.io.naver.com/jackpotlog/v1/logs","sspndpsdk":"https://ssl.pstatic.net/tveta/libs/ndpsdk/prod","gn_stndard":"https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn","sellerBlog":"https://seller.blog.naver.com","lcs":"lcs.naver.com","ad":"https://siape.veta.naver.com","id_secret":"https://nid.naver.com","likeitcdn":"https://static-like.pstatic.net","nmobile":"https://m.blog.naver.com","spi":"https://ssl.pstatic.net/spi","blog_proxy":"https://proxy.blog.naver.com","blogprofilethumb":"https://blogpfthumb-phinf.pstatic.net","help":"http://help.naver.com","uns":"https://notice.naver.com","thumbnail2":"https://blogthumb.pstatic.net"};
#         var isLikeUseProxy = false;
#         var g_ssc = "blog.mainv2";
#         var isSocialUseProxy = false;
#         var isGladSdkNew = false;
#
#         // 팝업을 통해서 부모창을 제어하기 위해 필요
#         // document.domain = 'naver.com';
#         //튜토리얼 css 가 제대로 동작안해서 필요
#         var doc = document.documentElement;
#         doc.setAttribute('data-useragent',navigator.userAgent);
#         var uploadURL = "https://upload.blog.naver.com";
#         var userNaverId = "";
#     </script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/t.static.blog/section/versioning//common/js/lottie.min-0e23629_https.js"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/t.static.blog/section/versioning/NgAppBundle1-1693215087_https.js" charset="UTF-8"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/t.static.blog/section/versioning/NgAppBundle2-1927322194_https.js" charset="UTF-8"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/t.static.blog/section/versioning/NgTemplate-471391437_https.js" charset="UTF-8"></script>
#
# </head>
# <template id="blogDomainRegisterLayerTemplate">
#     <div id="sellerAlertLayer" class="SetBlogId_layer_wrap" style="display:none;">
#         <div class="caution_alert_content">
#             <i class="icon"></i>
#             <div class="text_area">
#                 <strong class="title">블로그 주소 변경 불가 안내</strong>
#                 <p class="desc">
#                     블로그 마켓 판매자의 이력 관리를 위해<br>
#                     블로그 주소 변경이 불가합니다.
#                 </p>
#             </div>
#             <div class="btn_area">
#                 <a href="https://help.naver.com/alias/blog/blogmarket/blogmarket14.naver" class="btn">자세히 보기</a>
#                 <button id="sellerAlertLayerClose" type="button" class="close_btn">레이어 닫기</button>
#             </div>
#         </div>
#     </div>
#
#     <div id="blogDomainRegisterSuggestionLayer" class="SetBlogId_layer_wrap IntroBlogId_layer" style="display: none;">
#         <div class="BlogId_content">
#             <div class="img_area">
#                 <img src="https://ssl.pstatic.net/static/blog/img_ani_blogid1.gif" width="335" height="260" class="img" alt="블로그 아이디가 필요해요!">
#             </div>
#             <div class="text_area">
#                 <strong class="title">블로그 아이디가 필요해요!</strong>
#                 <p class="desc">
#                     블로그에서 진짜 나를 기록하고<br>
#                     다양한 이웃과 소식을 만나보세요. 지금 시작해볼까요?
#                 </p>
#             </div>
#             <div class="btn_area">
#                 <a id="blogDomainRegisterStartBtn" onclick="nclk_v2(this, 'bsu.popupok', '', '');return false;" class="btn">블로그 아이디 만들기</a>
#                 <a id="blogDomainRegisterSuggestionLayerCloseBtn" onclick="nclk_v2(this, 'bsu.popupclose', '', '');return false;" class="close_btn">블로그 아이디 만들기 레이어 닫기</a>
#             </div>
#         </div>
#     </div>
#
#     <div id="domainInputLayer" class="SetBlogId_layer_wrap" style="display: none;">
#         <div class="BlogId_content">
#             <h1 id="blogDomainTitle" class="title_h1"></h1>
#             <div class="domain">
#                 blog.naver.com/<strong id="domainIdInfo" class="blogid"></strong>
#             </div>
#             <!-- 오류 .error -->
#             <!-- 인증 성공 .success -->
#             <div id="blogidMessageWrap" class="input_blogid_area">
#                 <input id="domainInput" class="input_text" type="text" placeholder="블로그아이디" maxlength="20" autocomplete="off">
#                 <div class="right_area">
#                     <button id="clearDomainInputBtn" type="button" class="del_btn" style="display: none">
#                         입력 내용 삭제
#                     </button>
#                     <!-- 아이디 입력중 -->
#                     <i class="loading_icon" id="loading_icon"></i>
#                 </div>
#                 <div id="domainMessage" class="message"></div>
#             </div>
#             <div id= "recommendDomainIdDiv" class="recommend_blogid">
#                 <ul id="recommendDomainId" class="list">
#                 </ul>
#             </div>
#             <div class="desc_area">
#                 <ul class="list">
#                     <li class="item">
#                         설정한 아이디는 나중에 변경할 수 없으니 신중하게 입력해주세요.
#                     </li>
#                     <li class="item blogDomainChangeOnlyViewDesc">
#                         변경 전 공유된 블로그/글/클립 링크는 연결이 끊길 수 있습니다.
#                     </li>
#                     <li class="item">
#                         <strong class="strong">네이버 아이디 또는 개인정보가 포함된 문자 사용</strong>은 피해주세요.
#                     </li>
#                     <li class="item blogDomainChangeOnlyViewDesc">
#                         블로그 도움말에서 아이디 변경 유의사항을 확인해보세요.
#                     </li>
#                 </ul>
#             </div>
#             <div class="btn_area">
#                 <button id="blogDomainRegisterCancelBtn" type="button" class="cancel_btn">
#                     나중에 할게요
#                 </button>
#                 <input id="domainRegisterBtn" type="submit" value="확인" class="submit_btn" onclick="return false;" disabled="">
#             </div>
#         </div>
#     </div>
#
#     <div id="domainChangeConfirmLayer" class="SetBlogId_layer_wrap SetBlogIdAlert_wrap" style="display:none;">
#         <div class="SetBlogIdAlert_content">
#             <div class="blogid_area">
#                 <div id="changeConfirmDomainId" class="blogid"></div>
#                 <div id="changeConfirmDomainURL" class="domain"></div>
#             </div>
#             <div class="text_area">
#                 <p class="text_small">
#                     1. 이전 주소로 공유된 글은<br>
#                     3개월간 새로운 주소로 연결을 지원하며<br>
#                     이후 언제든 연결이 끊길 수 있습니다.
#                 </p>
#                 <p class="text_small">
#                     2. 블로그 아이디는 한번 변경하면<br>
#                     <strong class="red_color">다시 변경이 불가능</strong>합니다.
#                 </p>
#                 <p class="text_small">
#                     <strong>변경하시겠습니까?</strong>
#                 </p>
#             </div>
#             <div class="btn_area">
#                 <button id="changeConfirmCancleBtn" type="button" class="btn">취소</button>
#                 <button id="changeConfirmSubmitBtn" type="button" class="btn">확인</button>
#             </div>
#         </div>
#     </div>
#
#     <div id="domainConfirmLayer" class="SetBlogId_layer_wrap SetBlogIdAlert_wrap" style="display:none;">
#         <div class="SetBlogIdAlert_content">
#             <div class="blogid_area">
#                 <div class="img_area">
#                     <img src="https://ssl.pstatic.net/static/blog/img_ani_blogid2.gif" width="208" height="86" alt="섬네일">
#                 </div>
#                 <div id="confirmDomainId" class="blogid"></div>
#                 <div id="confirmDomainURL" class="domain"></div>
#             </div>
#             <div class="text_area">
#                 <p class="text_red">
#                     블로그 아이디는 한번 정하면
#                     <br>
#                     다시 변경이 불가능합니다.
#                 </p>
#                 <p class="text">이 아이디로 블로그를 만들까요?</p>
#             </div>
#             <div class="btn_area">
#                 <button id="confirmCancleBtn" type="button" class="btn">취소</button>
#                 <button id="confirmSubmitBtn" type="button" class="btn">확인</button>
#             </div>
#         </div>
#     </div>
#
#     <div id="domainWelcomeLayer" class="SetBlogId_layer_wrap WelcomeSetBlogId_layer_wrap" style="display:none">
#         <div class="BlogId_content">
#             <h1 class="title_h1">
#                 환영합니다!<br>
#                 블로그 아이디가 만들어졌어요.
#             </h1>
#             <div class="img_area">
#                 <img src="https://ssl.pstatic.net/static/blog/img_ani_blogid3_2.gif" class="img" width="500" height="281" alt="섬네일"/>
#             </div>
#             <div class="text_area">
#                 <div id="welcomeBlogId" class="blogid"></div>
#                 <div id="welcomeBlogURL" class="domain">
#                     blog.naver.com/
#                 </div>
#             </div>
#             <div class="btn_area">
#                 <a id="closeWelcomeLayer" onclick="nclk_v2(this, 'bsu*i.start', '', '');return false;" class="btn blue">바로 시작하기</a>
#                 <a id="nextStep" onclick="nclk_v2(this, 'bsu*i.inform', '', '');return false;" class="btn green">추가정보 입력하기</a>
#             </div>
#         </div>
#     </div>
#
#     <div id="blogBasicInfoLayer" class="SetBlogId_layer_wrap InputBlogId_layer_wrap" style="display:none">
#         <div class="BlogId_content">
#             <h1 class="title_h1">기본정보를 입력해주세요.</h1>
#             <p class="title_desc">나중에 언제든지 변경할 수 있어요.</p>
#             <div class="profile_area">
#                 <div class="profile">
#                     <div id="blogDomainProfileImage" class="img" title="" style="background-image: url(https://ssl.pstatic.net/static/blog/profile/Profile_defaultIMG_A@2x.png);"></div>
#                 </div>
#                 <button id="profileSetBtn" onclick="nclk_v2(this, 'bsu*p.profile', '', '');return false;"  type="button" class="profile_set_btn">프로필 이미지 설정</button>
#                 <div id="profileSetLayer" class="profile_set_layer">
#                     <div class="top_btn_area">
#                         <button id="profileImageClear" onclick="nclk_v2(this, 'bsu*p.prfdelete', '', '');" type="button" class="del_btn">지우기</button>
#                         <div class="file_btn">
#                             <label class="label" for="profile_upload_btn">사진 업로드</label>
#                             <input type="file" onclick="nclk_v2(this, 'bsu*p.prfupload', '', '');" id="profile_upload_btn" class="input_file" accept=".png, .jpg, .jpeg, .gif, .bmp"/>
#                         </div>
#                     </div>
#                     <ul id="profilePresetList" class="profile_list">
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop1', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_01.png" width="59" height="59" class="img" alt="프리셋1"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop2', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_02.png" width="59" height="59" class="img" alt="프리셋2"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop3', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_03.png" width="59" height="59" class="img" alt="프리셋3"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop4', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_04.png" width="59" height="59" class="img" alt="프리셋4"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop5', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_05.png" width="59" height="59" class="img" alt="프리셋5"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop6', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_06.png" width="59" height="59" class="img" alt="프리셋6"  /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop7', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_07.png" width="59" height="59" class="img" alt="프리셋7" /></button>
#                         </li>
#                         <li class="item">
#                             <button type="button" onclick="nclk_v2(this, 'bsu*p.prfop8', '', '');" class="btn"><img src="https://ssl.pstatic.net/static/blog/profile/img_profile_preset_08.png" width="59" height="59" class="img" alt="프리셋8" /></button>
#                         </li>
#                     </ul>
#                     <div class="btn_area">
#                         <button id="proflieImageCancelBtn" onclick="nclk_v2(this, 'bsu*p.prfccl', '', '');" type="button" class="cancel_btn">취소</button>
#                         <button id="proflieImageSelectedBtn" onclick="nclk_v2(this, 'bsu*p.prfok', '', '');" type="button" class="submit_btn">적용</button>
#                     </div>
#                 </div>
#             </div>
#             <div class="input_area">
#                 <div class="input">
#                     <label class="label" for="nickname">별명</label>
#                     <input onclick="nclk_v2(this, 'bsu*p.nickname', '', '');" type="text" class="input_text" id="nickname" maxlength="20" autocomplete="off"/>
#                 </div>
#                 <div class="input">
#                     <label class="label" for="blogname">블로그명</label>
#                     <input onclick="nclk_v2(this, 'bsu*p.blogname', '', '');" type="text" class="input_text" id="blogname" maxlength="50" autocomplete="off"/>
#                 </div>
#                 <div class="input">
#                     <label class="label">블로그 주제</label>
#                     <button id="showBlogThemeList" onclick="nclk_v2(this, 'bsu*p.blogtopic', '', '');" type="button" class="theme_btn">주제 없음</button>
#                     <div id="basicInfoBlogThemeList" class="theme_list_layer">
#                         <strong class="title">엔터테인먼트·예술</strong>
#                         <ul class="list">
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option1', '', '');" class="input_radio" name="theme"  id="theme1" data-directoryseq="5">
#                                 <label for="theme1" class="label">문학·책</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option2', '', '');" class="input_radio" name="theme" id="theme2" data-directoryseq="6">
#                                 <label for="theme2" class="label">영화</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option3', '', '');" class="input_radio" name="theme" id="theme3" data-directoryseq="8">
#                                 <label for="theme3" class="label">미술·디자인</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option4', '', '');" class="input_radio" name="theme" id="theme4" data-directoryseq="7">
#                                 <label for="theme4" class="label">공연·전시</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option5', '', '');" class="input_radio" name="theme" id="theme5" data-directoryseq="11">
#                                 <label for="theme5" class="label">음악</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option6', '', '');" class="input_radio" name="theme" id="theme6" data-directoryseq="9">
#                                 <label for="theme6" class="label">드라마</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option7', '', '');" class="input_radio" name="theme" id="theme7" data-directoryseq="12">
#                                 <label for="theme7" class="label">스타·연예인</label>
#                             </li>
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option8', '', '');" class="input_radio" name="theme" id="theme8" data-directoryseq="13">
#                                 <label for="theme8" class="label">만화·애니</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option9', '', '');" class="input_radio" name="theme" id="theme9" data-directoryseq="10">
#                                 <label for="theme9" class="label">방송</label>
#                             </li>
#                         </ul>
#                         <strong class="title">생활·노하우·쇼핑</strong>
#                         <ul class="list">
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option10', '', '');" class="input_radio" name="theme" id="theme10" data-directoryseq="14">
#                                 <label for="theme10" class="label">일상·생각</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option11', '', '');" class="input_radio" name="theme" id="theme11" data-directoryseq="15">
#                                 <label for="theme11" class="label">육아·결혼</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option12', '', '');" class="input_radio" name="theme" id="theme12" data-directoryseq="16">
#                                 <label for="theme12" class="label">반려동물</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option13', '', '');" class="input_radio" name="theme" id="theme13" data-directoryseq="17">
#                                 <label for="theme13" class="label">좋은글·이미지</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option14', '', '');" class="input_radio" name="theme" id="theme14" data-directoryseq="18">
#                                 <label for="theme14" class="label">패션·미용</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option15', '', '');" class="input_radio" name="theme" id="theme15" data-directoryseq="19">
#                                 <label for="theme15" class="label">인테리어·DIY</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option16', '', '');" class="input_radio" name="theme" id="theme16" data-directoryseq="20">
#                                 <label for="theme16" class="label">요리·레시피</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option17', '', '');" class="input_radio" name="theme" id="theme17" data-directoryseq="21">
#                                 <label for="theme17" class="label">상품리뷰</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option18', '', '');" class="input_radio" name="theme" id="theme18" data-directoryseq="36">
#                                 <label for="theme18" class="label">원예·재배</label>
#                             </li>
#                         </ul>
#                         <strong class="title">취미·여가·여행</strong>
#                         <ul class="list">
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option19', '', '');" onclick="nclk_v2(this, 'bsu*p.option1', '', '');" class="input_radio" name="theme" id="theme19" data-directoryseq="22">
#                                 <label for="theme19" class="label">게임</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option20', '', '');" class="input_radio" name="theme" id="theme20" data-directoryseq="23">
#                                 <label for="theme20" class="label">스포츠</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option21', '', '');" class="input_radio" name="theme" id="theme21" data-directoryseq="24">
#                                 <label for="theme21" class="label">사진</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option22', '', '');" class="input_radio" name="theme" id="theme22" data-directoryseq="25">
#                                 <label for="theme22" class="label">자동차</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option23', '', '');" class="input_radio" name="theme" id="theme23" data-directoryseq="26">
#                                 <label for="theme23" class="label">취미</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option24', '', '');" class="input_radio" name="theme" id="theme24" data-directoryseq="27">
#                                 <label for="theme24" class="label">국내여행</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option25', '', '');" class="input_radio" name="theme" id="theme25" data-directoryseq="28">
#                                 <label for="theme25" class="label">세계여행</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option26', '', '');" class="input_radio" name="theme" id="theme26" data-directoryseq="29">
#                                 <label for="theme26" class="label">맛집</label>
#                             </li>
#                         </ul>
#                         <strong class="title">지식·동향</strong>
#                         <ul class="list">
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option27', '', '');" class="input_radio" name="theme" id="theme27" data-directoryseq="30">
#                                 <label for="theme27" class="label">IT·컴퓨터</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option28', '', '');" class="input_radio" name="theme" id="theme28" data-directoryseq="31">
#                                 <label for="theme28" class="label">사회·정치</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option29', '', '');" class="input_radio" name="theme" id="theme29" data-directoryseq="32">
#                                 <label for="theme29" class="label">건강·의학</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option30', '', '');" class="input_radio" name="theme" id="theme30" data-directoryseq="33">
#                                 <label for="theme30" class="label">비즈니스·경제</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option31', '', '');" class="input_radio" name="theme" id="theme31" data-directoryseq="35">
#                                 <label for="theme31" class="label">어학·외국어</label>
#                             </li>
#
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option32', '', '');" class="input_radio" name="theme" id="theme32" data-directoryseq="34">
#                                 <label for="theme32" class="label">교육·학문</label>
#                             </li>
#                         </ul>
#                         <strong class="title">주제없음</strong>
#                         <ul class="list">
#                             <li class="item">
#                                 <input type="radio" onclick="nclk_v2(this, 'bsu*p.option33', '', '');" class="input_radio" name="theme" id="theme33" data-directoryseq="0">
#                                 <label for="theme33" class="label">주제 선택 보류</label>
#                             </li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#             <div class="btn_area">
#                 <button id="closeBlogBasicInfoLayer" onclick="nclk_v2(this, 'bsu*p.ccl', '', '', event);"  type="button" class="cancel_btn">
#                     나중에 할게요
#                 </button>
#                 <input id="submitBlogBasicInfo" onClick="nclk_v2(this, 'bsu*p.next', '', ''); return false;" type="submit" value="다음" class="submit_btn" />
#             </div>
#             <div class="pagination_area">
#                 <i class="item is_active">기본정보 입력</i>
#                 <i class="item">관심분야 선택</i>
#                 <i class="item">이웃 맺기</i>
#             </div>
#             <div class="back_btn_area">
#                 <button id="blogBasicInfoBackBtn" onclick="nclk_v2(this, 'bsu*p.previous', '', '');" type="button" class="back_btn">뒤로가기 버튼</button>
#             </div>
#         </div>
#     </div>
#
#     <div id="personalThemeLayer" class="SetBlogId_layer_wrap InputBlogId_layer_wrap" style="display:none">
#         <div class="BlogId_content">
#             <h1 class="title_h1">관심분야를 선택해주세요.</h1>
#             <p class="title_desc">선택한 분야의 글과 이웃을 추천받을 수 있어요.</p>
#             <div class="recommendation_list">
#                 <ul id="personalThemeList" class="list">
#
#                 </ul>
#             </div>
#             <div class="btn_area">
#                 <button id="personalThemeSelectCancel" onClick="nclk_v2(this, 'bsu*t.ccl', '', '');" type="button" class="cancel_btn">
#                     나중에 할게요
#                 </button>
#                 <!-- 사용할 수 있는 아이디 입력시 disabled 삭제 -->
#                 <input id="personalThemeSubmitBtn" onclick="nclk_v2(this, 'bsu*t.next', '', ''); return false;" type="submit" value="다음" class="submit_btn" />
#             </div>
#             <div class="pagination_area">
#                 <i class="item">기본정보 입력</i>
#                 <i class="item is_active">관심분야 선택</i>
#                 <i class="item">이웃 맺기</i>
#             </div>
#             <div class="back_btn_area">
#                 <button id="personalThemeBackBtn" onclick="nclk_v2(this, 'bsu*t.previous', '', '');" type="button" class="back_btn">뒤로가기 버튼</button>
#             </div>
#         </div>
#     </div>
#
#     <div id="recommendBlogLayer" class="SetBlogId_layer_wrap InputBlogId_layer_wrap" style="display:none;">
#         <div class="BlogId_content">
#             <h1 class="title_h1">인기블로거와 이웃을 맺으세요.</h1>
#             <p class="title_desc">이웃을 맺으면 이웃새글에서 글을 받아볼 수 있어요.</p>
#             <div class="bloger_list">
#                 <ul id="recommendBlogList" class="list">
#
#                 </ul>
#                 <div class="loading_wrap" id="recommendBlogList_loading_wrap">
#                     <div class="colordot_loading">
#                         <i class="dot dot1"></i>
#                         <i class="dot dot2"></i>
#                         <i class="dot dot3"></i>
#                         <i class="dot dot4"></i>
#                         <i class="dot dot5"></i>
#                         <i class="dot dot6"></i>
#                     </div>
#                 </div>
#             </div>
#             <div class="btn_area">
#                 <button id="startBlogBtn" onclick="nclk_v2(this, 'bsu*r.start', '', '');" type="button" class="start_blog_btn">
#                     블로그 시작하기
#                 </button>
#             </div>
#             <div class="pagination_area">
#                 <i class="item">기본정보 입력</i>
#                 <i class="item">관심분야 선택</i>
#                 <i class="item is_active">이웃 맺기</i>
#             </div>
#             <div class="back_btn_area">
#                 <button id="recommendBackBtn" onclick="nclk_v2(this, 'bsu*r.previous', '', '');" type="button" class="back_btn">뒤로가기 버튼</button>
#             </div>
#             </fieldset>
#             </form>
#         </div>
#     </div>
#
#
#     <div class="SetBlogId_layer_wrap" style="display:none;" id="alertLayer">
#         <div class="ui_alert_content">
#             <div class="text_area">
#                 <p class="desc" id="alertMessage"></p>
#             </div>
#             <div class="btn_area">
#                 <button type="button" class="btn" id="closeAlertLayer">확인</button>
#             </div>
#         </div>
#     </div>
#
#     <div class="SetBlogId_layer_wrap" style="display:none;" id="alertLayeCallBack">
#         <div class="ui_alert_content">
#             <div class="text_area">
#                 <p class="desc" id="alertMessageCallBack"></p>
#             </div>
#             <div class="btn_area">
#                 <button type="button" class="btn" id="closeAlertLayerCallBack">확인</button>
#             </div>
#         </div>
#     </div>
# </template>
#
# <template id="blogDomainRegisterPopularBlogTemplate" style="display: none">
#     <li class="item">
#         <div class="bloger_item">
#             <div class="bloger">
#                 <div class="profile_img">
#                     <img data-src="profileImage" width="56" height="56" class="img" alt="프로필" />
#                 </div>
#                 <div class="profile_text">
#                     <strong data-content="nickName" class="nickname"></strong>
#                     <span data-content="blogName" class="blogname"></span>
#                     <span data-content="themeName" class="category"></span>
#                 </div>
#             </div>
#             <div class="post_list_wrap">
#                 <ul data-innerHTML="postList" class="list">
#                 </ul>
#             </div>
#             <button type="button" class="add_buddy_btn _recommendBuddyAdd" data-template-bind='[{"attribute": "style", "value": "buddyAddDisplayStyle"}, {"attribute": "data-domainIdOrBlogId", "value": "domainIdOrBlogId"}]'>이웃추가</button>
#             <button class="buddy _recommendBuddyRemove" data-template-bind='[{"attribute": "style", "value": "buddyDisplayStyle"}, {"attribute": "data-domainIdOrBlogId", "value": "domainIdOrBlogId"}]'>이웃</button>
#         </div>
#     </li>
# </template>
#
# <template id="blogDomainRegisterPopularBlogPostTemplate" style="display: none">
#     <li class="item">
#         <div class="img_area">
#             <img data-src="mainThumbnailUrl" class="img" alt="섬네일" />
#         </div>
#         <div class="text_area">
#             <strong data-content="title" class="title"></strong>
#             <p class="desc" data-content="briefContents"></p>
#         </div>
#     </li>
# </template>
#
# <template id="personalThemeTemplate" style="display: none">
#     <li class="item">
#         <div class="recommend_item">
#             <input type="checkbox" class="inputbox" data-template-bind='[{"attribute": "id", "value": "id"}]'>
#             <label data-template-bind='[
#                 {"attribute": "for", "value": "id"},
#                 {"attribute": "data-directorySeq", "value": "directorySeq"},
#                 {"attribute": "data-clickCode", "value": "clickCode"}]' data-content="themeName" class="label"></label>
#         </div>
#     </li>
# </template>
# <body bg-body-click>
# <ui-view autoscroll="true"></ui-view>
# </body>
# <script>
#
#     if(userAgentUtil.isNotSupportBrowser()){
#         alert('IE8 이하 브라우저에서는 "신규버전 보기"를 제공하지 않습니다.\n브라우저 업데이트를 부탁드립니다.');
#         location.href = '/SectionMain.nhn';
#     }else{
#         angular.element(document).ready(function() {
#             angular.bootstrap(document, ['bgApp'], {
#                 strictDi: true
#             });
#         });
#     }
#
# </script>
# <script type="text/javascript" src="https://notice.naver.com/static/js/iframeListener.js"></script>
#
#
#     <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js"></script>
#
# </html>

# %% [markdown]
# ## 3.3 웹 스크래핑 - beautifulsoup (4/10일 비대면 수업)
# * 웹 페이지 정보 추출하기 - beautifulsoup 사용법
#   * soup.select_one()
#   * soup.select()
#   * get_text()
# * 개발자 도구 사용

# %% [markdown]
# ### [문제] 네이버 지식iN의 검색어 관련 검색 결과 제목 가져오기
# * 타겟 웹 사이트 : https://kin.naver.com/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC
# * soup.select_one()
# * soup.select()
# * 개발자 도구을 이용

# %%
import requests
from bs4 import BeautifulSoup

# 1. 타겟 웹 사이트 url
url = 'https://kin.naver.com/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# 2. 웹 페이지 로딩
response = requests.get(url)

if response.status_code == 200:
    # 웹 페이지 확인
    html = response.text
    # 4. html -> beautifulsoup 객체로 변환 : 원하는 데이터을 쉽게 추출
    soup = BeautifulSoup(html, 'html.parser')

    # 5. 데이터 추출 : 첫 번째 제목 선택하여 가져오기
    title = soup.select_one('#s_content > div.section > ul > li:nth-child(1) > dl > dt > a')
    # print(title)
    # print(title.get_text())

    # 6. 데이터 추출 : 제목 여러 개 선택하여 리스트 구조 가져오기
    titles = soup.select('#s_content > div.section > ul > li:nth-child(n) > dl > dt > a')
    # print(titles)

    # 7. 제목의 텍스트을 반복적으로 적용하여 가져오기
    for title in titles:
        print(title.get_text())
        
else : 
    print(response.status_code)
# Out:
# 파이썬이 미래에 도움이 될까요?
# 파이썬 사용
# 웹개발공부와 파이썬공부
# 맥북 파이썬 idel
# 파이썬 질문
# 파이썬과 자바
# 파이썬 질문...
# 파이썬 배우기
# 파이썬강좌 독학할때 뭐보나요??
# 파이썬독학할 때 어떻게 공부를...

# %% [markdown]
# ## 3.4 웹 스크래핑 - Selenium을 이용하여 크롤러
# *  https://selenium-python.readthedocs.io/
# * selenium 사용법
#   1. 시스템의 OS 및 Chrome 브라우저의 버전 확인
#   2. Chrome 드라이버 다운로드 및 설치
#   3. 크롬 드라이버을 프로젝트 폴더에 저장 - 크롬 드라이버의 설치 경로
#      * from selenium import webdriver
#      * driver = webdriver.Chrome()
# * 동적으로 웹 페이지 정보 추출하기
#      * driver.get("웹주소")

# %% [markdown]
# ### [예제] Selenium을 이용하여 자동으로 타겟 웹 사이트 실행하기
# * 타겟 사이트 : https://www.google.com

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (4.19.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hyung\onedrive\바탕 화면\python_basic_2\venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
# 1. Chrome 브라우저 실행
driver = webdriver.Chrome() # 크롬 드라이버 실행파일의 위치 - 작업디렉터리
# 2. 타겟 웹페이지 로딩
url = "https://www.google.com"
driver.get(url)
# 3. 타겟 브라우저 종료
driver.quit()
# Out:
# ----------------------------------------------------------------------
# WebDriverException                   Traceback (most recent call last)
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:106, in SeleniumManager.driver_location(self, options)
#     104     args.append(value)
# --> 106 output = self.run(args)
#     108 browser_path = output["browser_path"]
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:154, in SeleniumManager.run(args)
#     153 if completed_proc.returncode:
# --> 154     raise WebDriverException(f"Unsuccessful command executed: {command}.\n{result}{stderr}")
#     155 return result
#
# WebDriverException: Message: Unsuccessful command executed: C:\Users\hyung\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\windows\selenium-manager.exe --browser chrome --language-binding python --output json.
# {'code': 69, 'message': 'Driver unavailable: Driver path: ', 'driver_path': '', 'browser_path': ''}
#
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                Traceback (most recent call last)
# Cell In[42], line 3
#       1 from selenium import webdriver
#       2 # 1. Chrome 브라우저 실행
# ----> 3 driver = webdriver.Chrome() # 크롬 드라이버 실행파일의 위치 - 작업디렉터리
#       4 # 2. 타겟 웹페이지 로딩
#       5 url = "https://www.google.com"
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:49, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      37 """Creates a new WebDriver instance of the ChromiumDriver. Starts the
#      38 service and then creates new WebDriver instance of ChromiumDriver.
#      39
#    (...)
#      45  - keep_alive - Whether to configure ChromiumRemoteConnection to use HTTP keep-alive.
#      46 """
#      47 self.service = service
# ---> 49 self.service.path = DriverFinder.get_path(self.service, options)
#      50 self.service.start()
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:41, in DriverFinder.get_path(service, options)
#      39 except Exception as err:
#      40     msg = f"Unable to obtain driver for {options.capabilities['browserName']} using Selenium Manager."
# ---> 41     raise NoSuchDriverException(msg) from err
#      43 if path is None or not Path(path).is_file():
#      44     raise NoSuchDriverException(f"Unable to locate or obtain driver for {options.capabilities['browserName']}")
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome using Selenium Manager.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %% [markdown]
# ### [문제] Selenium을 이용하여 자동으로 타겟 웹 사이트 실행하기/검색하기/검색 결과 출력하기
# * 타겟 사이트: https://www.google.com
# * driver.find_element()
# * send_keys()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# 1. Chrome 브라우저 실행
driver = webdriver.Chrome()

# 2. 타겟 Google 홈페이지 열기
url = "https://www.google.com"
driver.get(url)

# 3. 페이지가 완전히 로드될 때까지 2초 대기
time.sleep(2)

# 4. 검색 기능 - 검색창-> 검색어 입력 -> 엔터 키로 클릭 처리
try:
    # 4-1 검색 상자 요소 찾기
    search_box = driver.find_element(By.NAME, "q") 

    # 4-2 검색어 입력
    search_query = "OpenAI"
    search_box.send_keys(search_query) 

    # 4-3 Enter 키를 눌러 검색 수행
    search_box.send_keys(Keys.RETURN)

    # 검색 결과가 로드될 때까지 5초 대기
    time.sleep(5)

    # 5. 검색에 관련된  결과 추출
    search_results = driver.find_elements(By.CSS_SELECTOR, "div.g") 
    
    # # 5-1 첫 번째 제목과 링크 url 추출
    # search_results = driver.find_elements(By.CSS_SELECTOR, "div.g") 
    # title = search_results[0].find_element(By.CSS_SELECTOR, "h3").text
    # url = search_results[0].find_element(By.CSS_SELECTOR, "a").get_attribute("href")
    # print("제목:", title)
    # print("URL:", url)

    # 5-2 검색 결과의 모든 제목과 링크 URL 인쇄
    for result in search_results:
        title = result.find_element(By.CSS_SELECTOR, "h3").text
        url = result.find_element(By.CSS_SELECTOR, "a").get_attribute("href")
        print("제목:", title)
        print("URL:", url)
    
except Exception as e:
    print("오류가 발생했습니다:", e)

finally:
    # 브라우저 창 닫기
    driver.quit()
# Out:
# ----------------------------------------------------------------------
# WebDriverException                   Traceback (most recent call last)
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:106, in SeleniumManager.driver_location(self, options)
#     104     args.append(value)
# --> 106 output = self.run(args)
#     108 browser_path = output["browser_path"]
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:154, in SeleniumManager.run(args)
#     153 if completed_proc.returncode:
# --> 154     raise WebDriverException(f"Unsuccessful command executed: {command}.\n{result}{stderr}")
#     155 return result
#
# WebDriverException: Message: Unsuccessful command executed: C:\Users\hyung\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\windows\selenium-manager.exe --browser chrome --language-binding python --output json.
# {'code': 69, 'message': 'Driver unavailable: Driver path: ', 'driver_path': '', 'browser_path': ''}
#
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                Traceback (most recent call last)
# Cell In[43], line 7
#       4 import time
#       6 # 1. Chrome 브라우저 실행
# ----> 7 driver = webdriver.Chrome()
#       9 # 2. 타겟 Google 홈페이지 열기
#      10 url = "https://www.google.com"
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:49, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      37 """Creates a new WebDriver instance of the ChromiumDriver. Starts the
#      38 service and then creates new WebDriver instance of ChromiumDriver.
#      39
#    (...)
#      45  - keep_alive - Whether to configure ChromiumRemoteConnection to use HTTP keep-alive.
#      46 """
#      47 self.service = service
# ---> 49 self.service.path = DriverFinder.get_path(self.service, options)
#      50 self.service.start()
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#
# File ~\OneDrive\바탕 화면\python_basic_2\venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:41, in DriverFinder.get_path(service, options)
#      39 except Exception as err:
#      40     msg = f"Unable to obtain driver for {options.capabilities['browserName']} using Selenium Manager."
# ---> 41     raise NoSuchDriverException(msg) from err
#      43 if path is None or not Path(path).is_file():
#      44     raise NoSuchDriverException(f"Unable to locate or obtain driver for {options.capabilities['browserName']}")
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome using Selenium Manager.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %% [markdown]
# ### [문제] Selenium을 이용하여 네이버 증권 웹페이지 열기/ 삼성전자 일별 시세 HTML가져오기/ 10페이지 내역 테이블 데이터 찾기/검색 결과를 데이터프레임으로 변환/저장하기
# * 타겟 사이트: https://finance.naver.com/item/sise.naver?code=005930*

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
#1. 크롬 드라이버 실행
driver= webdriver.Chrome()

# 2페이지 로딩 시간
time.sleep(2)

# 3. 크롤링 사이트 : 삼성전자의 일별 시세 페이지 URL 찾기
samsung_url ="https://finance.naver.com/item/sise_day.naver?code=005930&page=" #base url

# 4. 첫 페이지부터 3 페이지까지 테이블 담기
samsung_daily_kospi = [] # 리스트 선언
for num in range(1,10):
    full_url = samsung_url + str(num)
    # 4.1 해당 페이지 요청
    driver.get(full_url)
    
    
    try:
        # 4.2 페이지의 HTML 가져오기
        html = driver.page_source
        df = pd.read_html(html) # 테이블 구조 -> 데이터프레임
        # 4.3 결측치 처리 - 조건 색인을 이용한 불리언 인덱싱
        ## 조건 색인 인덱싱
        cond = df[0]['날짜'].notnull()
        samsung_day = df[0][cond]
        ## 리스트에 담기
        samsung_daily_kospi.append(samsung_day)       
        
    except Exception as e:
        print("Network Error",e)
    
    finally:
        driver.quit()

print(samsung_daily_kospi)
samsung_daily_kospi_all = pd.concat(samsung_daily_kospi) # 데이터프레임 합치기
print(samsung_daily_kospi_all.head())
# samsung_daily_kospi_all.to_csv("samsung_daily_kospi_2024_04/10.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #1. 크롬 드라이버 실행
# ----> 2 driver= webdriver.Chrome()
#       4 # 2페이지 로딩 시간
#       5 time.sleep(2)
#
# NameError: name 'webdriver' is not defined
